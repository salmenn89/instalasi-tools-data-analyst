# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Colab").getOrCreate()

# %%
df = spark.read.csv("/content/drive/MyDrive/data.csv", header=True, inferSchema=True)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipython-input-3051472883.py in <cell line: 0>()
# ----> 1 df = spark.read.csv("/content/drive/MyDrive/data.csv", header=True, inferSchema=True)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     836         if type(path) == list:
#     837             assert self._spark._sc._jvm is not None
# ...

# %%
import os

file_path = "/content/drive/MyDrive/data.csv"

if not os.path.exists(file_path):
    # If the file does not exist, it's likely Google Drive is not mounted or the path is wrong.
    print(f"ERROR: File not found at '{file_path}'.")
    print("Please ensure:")
    print("1. Google Drive is mounted (e.g., by running 'from google.colab import drive; drive.mount('/content/drive')' in a previous cell).")
    print("2. The file 'data.csv' actually exists in the root of your Google Drive.")
else:
    # If the file exists, proceed to read it with Spark
    df = spark.read.csv(file_path, header=True, inferSchema=True)
    print(f"Successfully loaded '{file_path}'.")
# Out:
# ERROR: File not found at '/content/drive/MyDrive/data.csv'.
# Please ensure:
# 1. Google Drive is mounted (e.g., by running 'from google.colab import drive; drive.mount('/content/drive')' in a previous cell).
# 2. The file 'data.csv' actually exists in the root of your Google Drive.

# %%
df = spark.read.csv("data.csv", header=True, inferSchema=True)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipython-input-1212134656.py in <cell line: 0>()
# ----> 1 df = spark.read.csv("data.csv", header=True, inferSchema=True)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     836         if type(path) == list:
#     837             assert self._spark._sc._jvm is not None
# ...

# %%
import os

file_path = "/content/drive/MyDrive/data.csv - Sheet1.csv"

if not os.path.exists(file_path):
    print(f"ERROR: File not found at '{file_path}'.")
    print("Please ensure:")
    print("1. Google Drive is mounted (e.g., by running 'from google.colab import drive; drive.mount('/content/drive')' in a previous cell).")
    print("2. The file 'data.csv - Sheet1.csv' actually exists in the root of your Google Drive.")
else:
    df = spark.read.csv(file_path, header=True, inferSchema=True)
    print(f"Successfully loaded '{file_path}'.")
# Out:
# ERROR: File not found at '/content/drive/MyDrive/data.csv - Sheet1.csv'.
# Please ensure:
# 1. Google Drive is mounted (e.g., by running 'from google.colab import drive; drive.mount('/content/drive')' in a previous cell).
# 2. The file 'data.csv - Sheet1.csv' actually exists in the root of your Google Drive.

# %%
import os

file_path = "/content/drive/MyDrive/data.csv - Sheet1.csv" # Assuming the file is in Google Drive MyDrive

if not os.path.exists(file_path):
    print(f"ERROR: File not found at '{file_path}'.")
    print("Please ensure:")
    print("1. Google Drive is mounted. If not, run 'from google.colab import drive; drive.mount(\"/content/drive\")' in a new cell.")
    print("2. The file 'data.csv - Sheet1.csv' actually exists in the root of your Google Drive with this exact filename.")
else:
    df = spark.read.csv(file_path, header=True, inferSchema=True)
    print(f"Successfully loaded '{file_path}'.")
# Out:
# ERROR: File not found at '/content/drive/MyDrive/data.csv - Sheet1.csv'.
# Please ensure:
# 1. Google Drive is mounted. If not, run 'from google.colab import drive; drive.mount("/content/drive")' in a new cell.
# 2. The file 'data.csv - Sheet1.csv' actually exists in the root of your Google Drive with this exact filename.

# %%
df = spark.read.csv("/content/drive/MyDrive/ColabNotebooks/data.csv", header=True, inferSchema=True)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipython-input-1079168846.py in <cell line: 0>()
# ----> 1 df = spark.read.csv("/content/drive/MyDrive/ColabNotebooks/data.csv", header=True, inferSchema=True)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     836         if type(path) == list:
#     837             assert self._spark._sc._jvm is not None
# ...

# %%
df = spark.read.csv("/content/drive/MyDrive/ColabNotebooks/data.csv", header=True, inferSchema=True)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipython-input-1079168846.py in <cell line: 0>()
# ----> 1 df = spark.read.csv("/content/drive/MyDrive/ColabNotebooks/data.csv", header=True, inferSchema=True)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     836         if type(path) == list:
#     837             assert self._spark._sc._jvm is not None
# ...

# %%
df = spark.read.csv("/content/drive/MyDrive/Salinandata.csv", header=True, inferSchema=True)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipython-input-4075053378.py in <cell line: 0>()
# ----> 1 df = spark.read.csv("/content/drive/MyDrive/Salinandata.csv", header=True, inferSchema=True)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     836         if type(path) == list:
#     837             assert self._spark._sc._jvm is not None
# ...

# %%
path = "/content/drive/MyDrive/Colab Notebooks/data.csv"
df = spark.read.csv(path, header=True, inferSchema=True)
df.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# /tmp/ipython-input-615363169.py in <cell line: 0>()
#       1 path = "/content/drive/MyDrive/Colab Notebooks/data.csv"
# ----> 2 df = spark.read.csv(path, header=True, inferSchema=True)
#       3 df.show()
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     836         if type(path) == list:
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Colab").getOrCreate()
df = spark.read.csv("/content/drive/MyDrive/data1.csv", header=True, inferSchema=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4203509284.py in <cell line: 0>()
# ----> 1 df = spark.read.csv("/content/drive/MyDrive/data1.csv", header=True, inferSchema=True)
#
# NameError: name 'spark' is not defined

# %%
# !pip install pyspark

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pyspark.sql import SparkSession

# Membuat session Spark
spark = SparkSession.builder \
    .appName("TugasDataAnalyst") \
    .getOrCreate()

# %%
df = spark.read.csv("/content/drive/MyDrive/data1.csv", header=True, inferSchema=True)

# %%
df.show(5)
# Out:
# ++
# ||
# ++
# ++

# %%
df = spark.read.csv("/content/data1 - data1.csv", header=True, inferSchema=True)

# %%
df.show()
# Out:
# +------+----+--------------------+------------+-------------+
# |  nama|umur|              alamat|tinggi badan|jenis kelamin|
# +------+----+--------------------+------------+-------------+
# |  ical|  20|pasar jengkol blo...|         165|    laki-laki|
# |salman|  20|villa dago tol bl...|         166|    laki-laki|
# | syifa|  19|villa dago tol bl...|         158|    perempuan|
# |  ajis|  22|pondok pucuk h9 n...|         168|    laki-laki|
# | sadam|  22|villa melati mas ...|         165|    laki-laki|
# +------+----+--------------------+------------+-------------+

# %%
df.printSchema()
# Out:
# root
#  |-- nama: string (nullable = true)
#  |-- umur: integer (nullable = true)
#  |-- alamat: string (nullable = true)
#  |-- tinggi badan: integer (nullable = true)
#  |-- jenis kelamin: string (nullable = true)

# %%
df.describe().show()
# Out:
# +-------+-----+------------------+--------------------+------------------+-------------+
# |summary| nama|              umur|              alamat|      tinggi badan|jenis kelamin|
# +-------+-----+------------------+--------------------+------------------+-------------+
# |  count|    5|                 5|                   5|                 5|            5|
# |   mean| NULL|              20.6|                NULL|             164.4|         NULL|
# | stddev| NULL|1.3416407864998734|                NULL|3.7815340802378077|         NULL|
# |    min| ajis|                19|pasar jengkol blo...|               158|    laki-laki|
# |    max|syifa|                22|villa melati mas ...|               168|    perempuan|
# +-------+-----+------------------+--------------------+------------------+-------------+

# %%
df.select("nama", "alamat").show()
# Out:
# +------+--------------------+
# |  nama|              alamat|
# +------+--------------------+
# |  ical|pasar jengkol blo...|
# |salman|villa dago tol bl...|
# | syifa|villa dago tol bl...|
# |  ajis|pondok pucuk h9 n...|
# | sadam|villa melati mas ...|
# +------+--------------------+

# %%
df.filter(df["jenis kelamin"] == "perempuan").show()
# Out:
# +-----+----+--------------------+------------+-------------+
# | nama|umur|              alamat|tinggi badan|jenis kelamin|
# +-----+----+--------------------+------------+-------------+
# |syifa|  19|villa dago tol bl...|         158|    perempuan|
# +-----+----+--------------------+------------+-------------+

# %%
df.printSchema()
# Out:
# root
#  |-- nama: string (nullable = true)
#  |-- umur: integer (nullable = true)
#  |-- alamat: string (nullable = true)
#  |-- tinggi badan: integer (nullable = true)
#  |-- jenis kelamin: string (nullable = true)

# %%
df.groupBy("jenis kelamin").avg("umur").show()
# Out:
# +-------------+---------+
# |jenis kelamin|avg(umur)|
# +-------------+---------+
# |    perempuan|     19.0|
# |    laki-laki|     21.0|
# +-------------+---------+
